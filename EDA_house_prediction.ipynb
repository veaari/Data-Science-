# %% [markdown]
# <a href="https://colab.research.google.com/github/veaari/Data-Science-/blob/main/EDA_house_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Analysis
# Feature Engineering
# Feature Selection
# Model Building
# Model Deployment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.pandas .set_option('display.max_columns',None)

# %%
url ="https://raw.githubusercontent.com/krishnaik06/Advanced-House-Price-Prediction-/refs/heads/master/train.csv"
dataset = pd.read_csv(url)
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # **In Data Analysis We will Analyze To Find out the below stuff**
#
# 1.   Missing Values
# 2. All The Numerical Variables
# 3. Distribution of the Numerical Variables
# 4. Categorical Variables
# 5. Cardinality of Categorical Variables
# 6. Outliers
# 7. Relationship between independent and dependent feature(SalePrice)

# %%
features_with_na = [features for features in dataset.columns if dataset[features].isnull().sum()>1]
for feature in features_with_na:
  print(feature,np.round(dataset[feature].isnull().mean()*100,2),'% missing values')
# Out:
# LotFrontage 17.74 % missing values
# Alley 93.77 % missing values
# MasVnrType 59.73 % missing values
# MasVnrArea 0.55 % missing values
# BsmtQual 2.53 % missing values
# BsmtCond 2.53 % missing values
# BsmtExposure 2.6 % missing values
# BsmtFinType1 2.53 % missing values
# BsmtFinType2 2.6 % missing values
# FireplaceQu 47.26 % missing values
# GarageType 5.55 % missing values
# GarageYrBlt 5.55 % missing values
# GarageFinish 5.55 % missing values
# GarageQual 5.55 % missing values
# GarageCond 5.55 % missing values
# PoolQC 99.52 % missing values
# Fence 80.75 % missing values
# MiscFeature 96.3 % missing values

# %% [markdown]
# **Since they are many missing values, we need to find the relationship between missing values and Sales Price**

# %%
for feature in features_with_na:
  data = dataset.copy()
   # let's make a variable that indicates 1 if the observation was missing or zero otherwise
  data[feature] = np.where(data[feature].isnull(),1,0)
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.title(feature)
  plt.show()

# %% [markdown]
# ***here we conclude that the difference of missing values and the dependent variable are alot according to the saleprice of different feature soo we try to minimize the missing values differenciation***

# %%
# id not required
print("Id of Houses {}".format(len(dataset.Id)))
# Out:
# Id of Houses 1460

# %%
numerical_variables= [features for features in dataset.columns if dataset[features].dtypes !='O']
print("Numerical Variables {}".format(len(numerical_variables)))
dataset[numerical_variables].head()
# Out:
# Numerical Variables 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# # Temporal Variables(Eg: Datetime Variables) can be changed time to time
#
# From the Dataset we have 4 year variables. We have extract information from the datetime variables like no of years or no of days. One example in this specific scenario can be difference in years between the year the house was built and the year the house was sold. We will be performing this analysis in the Feature Engineering which is the next video.

# %%
year_feature = [feature for feature in numerical_variables if 'Year' in feature or 'Yr' in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let's explore the content of these year variables
#unique is used to get the distinct vaalues
for feature in year_feature:
    print(feature, dataset[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
## Lets analyze the Temporal Datetime Variables
## We will check whether there is a relation between year the house is sold and the sales price
dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
# Out:
# Text(0.5, 1.0, 'House Price vs YearSold')

# %%
## Here we will compare the difference between All years feature with SalePrice
for feature in year_feature:
  if feature != 'YrSold':
    data = dataset.copy()
    ## We will capture the difference between year variable and year the house was sold for
    data[feature]=data['YrSold']-data[feature]
    plt.scatter(data[feature],data['SalePrice'])
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %% [markdown]
# #Numerical variables are usually of 2 type
# ## 1. Continous variable
# A variable that can take any value within a range.
#
# ## 2.Discrete Variables
# A variable that can take specific, separate values only (often integers).

# %%
discrete_feature = [feature for feature in numerical_variables if len(dataset[feature].unique())<25 and feature not in year_feature+['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 17

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dataset[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
#finding the diff between thr discrete_features and the salePrice
# and the overallqual is monotonic relationship
for feature in discrete_feature:
  data = dataset.copy()
  data.groupby(feature)["SalePrice"].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel('SalePrice')
  plt.title(feature)
  plt.show()

# %% [markdown]
# #Continuous Variables

# %%
continuous_features = [feature for feature in numerical_variables if feature not in discrete_feature + year_feature+['Id']]
print("Continuous feature Count {}".format(len(continuous_features)))
# Out:
# Continuous feature Count 16

# %%
continuous_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
dataset[continuous_features].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# 0           61              0            0     208500
# ...

# %%
#analysing the continuous values with histograms
for feature in continuous_features:
  data = dataset.copy()
  data.groupby(feature)['SalePrice'].median().hist(bins=25)
  plt.xlabel(feature)
  plt.ylabel("Count")
  plt.title(feature)
  plt.show()

# %% [markdown]
#  ### A monotonic relationship means that as one variable goes up, the other always goes in one direction — either always up or always down.

# %%
#log transformation
for feature in continuous_features:
  data = dataset.copy()
  if 0 in data[feature].unique():
    pass
  else:
     data[feature] = np.log(data[feature])
     data['SalePrice'] = np.log(data['SalePrice'])
     plt.scatter(data[feature],data['SalePrice'])
     plt.xlabel(feature)
     plt.ylabel('SalesPrice')
     plt.title(feature)
     plt.show()

# %%
continuous_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in continuous_features:
  data = dataset.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    data.boxplot(column=feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# #Categorical Variable

# %%
categorical_features =[feature for feature in dataset.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
dataset[categorical_features].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_features:
  print(' this feature {} has categories of {}'.format(feature,len(dataset[feature].unique())))
# Out:
#  this feature MSZoning has categories of 5
#  this feature Street has categories of 2
#  this feature Alley has categories of 3
#  this feature LotShape has categories of 4
#  this feature LandContour has categories of 4
#  this feature Utilities has categories of 2
#  this feature LotConfig has categories of 5
#  this feature LandSlope has categories of 3
#  this feature Neighborhood has categories of 25
#  this feature Condition1 has categories of 9
#  this feature Condition2 has categories of 8
#  this feature BldgType has categories of 5
#  this feature HouseStyle has categories of 8
#  this feature RoofStyle has categories of 6
#  this feature RoofMatl has categories of 8
#  this feature Exterior1st has categories of 15
#  this feature Exterior2nd has categories of 16
#  this feature MasVnrType has categories of 4
#  this feature ExterQual has categories of 4
#  this feature ExterCond has categories of 5
#  this feature Foundation has categories of 6
# ...

# %%
## finding out the relationship between the categorical variable and the dependent feature SalesPrize

# %%
for feature in categorical_features:
  data = dataset.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel('SalesPrice')
  plt.title(feature)
  plt.show()
